# %%
# importing dependencies
import pandas as pd
import math

# %%
# reading in summary csv
summary_df = pd.read_csv('Resources/cluster_summary.csv')
summary_df
# Out:
#                                          cluster   kwh_ann_tot  \
# 0      sdge-com-SDG1-com_other-noKW-Care-0.0_0.2  7.756975e+04
# 1      sdge-com-SDG1-com_other-noKW-Care-0.2_0.4  2.386990e+05
# 2      sdge-com-SDG1-com_other-noKW-Care-0.4_0.6  4.120847e+05
# 3      sdge-com-SDG1-com_other-noKW-Care-0.6_0.8  1.420902e+06
# 4      sdge-com-SDG1-com_other-noKW-Care-0.8_1.0  1.620293e+07
# ..                                           ...           ...
# 196  sdge-res-SDG1-res_misc-noKW-nonCare-0.5_0.6  5.307001e+08
# 197  sdge-res-SDG1-res_misc-noKW-nonCare-0.6_0.7  6.197978e+08
# 198  sdge-res-SDG1-res_misc-noKW-nonCare-0.7_0.8  7.343816e+08
# 199  sdge-res-SDG1-res_misc-noKW-nonCare-0.8_0.9  9.138204e+08
# 200  sdge-res-SDG1-res_misc-noKW-nonCare-0.9_1.0  1.575237e+09
#
#      customer_count  util sector building_type rate_class  kwh_bin kw_bin
# 0                72  sdge    com     com_other       Care  0.0_0.2   noKW
# ...

# %%
# calculating total annual kwh
annual_sum_kwh = summary_df['kwh_ann_tot'].sum()
annual_sum_kwh
# Out:
# 19112559886.153946

# %%
# calculating building specific energy usage
building_kwh = summary_df[['building_type', 'kwh_ann_tot']].groupby('building_type').sum()

# sorting dataframe
building_kwh = building_kwh.sort_values('kwh_ann_tot', ascending=False)

building_kwh
# Out:
#                 kwh_ann_tot
# building_type
# res_misc       7.536514e+09
# office         4.725154e+09
# com_other      3.118775e+09
# retail         1.922126e+09
# ind_other      7.103688e+08
# comp_elec      3.747366e+08
# water          2.368621e+08
# plas_rub       1.854068e+08
# wwater         9.076598e+07
# chemical       8.495307e+07
# crop           4.915806e+07
# metals         4.547084e+07
# food_bev       2.980432e+07
# data_center    2.463881e+06

# %%
# creating list of building types of concern (excluding other)
building_list = summary_df['building_type'].unique()[1:]

# creating cluster list from building types to look up
cluster_list = summary_df.loc[summary_df['building_type'].isin(building_list)]['cluster']

# creating empty dataframe to append to
master_df = pd.DataFrame()

# looping through cluster list to open CSVs and append to master_df
for cluster in cluster_list:
    
    csv_item = "Resources/" + cluster + ".csv"
    
    building = cluster.split('-')[3]
    
    ds = pd.read_csv(csv_item)
    ds['building_type'] = building
    
    master_df = master_df.append(ds)
    
master_df
# Out:
# C:\Users\armck\AppData\Local\Continuum\anaconda3\envs\PythonData\lib\site-packages\pandas\core\frame.py:7138: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort,
#      building_type   cooling  hour_ending        hvac    lighting  \
# 0           office       NaN          1.0  247.092449  321.289100
# 1           office       NaN          2.0  237.623650  314.768353
# 2           office       NaN          3.0  241.887057  306.542408
# 3           office       NaN          4.0  250.317419  304.855163
# 4           office       NaN          5.0  266.098569  319.158525
# ...            ...       ...          ...         ...         ...
# 8755      res_misc  0.000000       8756.0         NaN         NaN
# ...

# %%
# calculating kwh per hour 
kwh_hr_df = master_df[['hour_ending', 'total']].groupby('hour_ending').sum()

# sorting list
kwh_hr_df = kwh_hr_df.sort_values('total', ascending=False)

kwh_hr_df
# Out:
#                     total
# hour_ending
# 6185.0       3.577323e+06
# 6208.0       3.572779e+06
# 6209.0       3.572120e+06
# 6186.0       3.536368e+06
# 6233.0       3.501773e+06
# ...                   ...
# 7348.0       1.195639e+06
# 2308.0       1.194629e+06
# 7661.0       1.191971e+06
# 7324.0       1.191421e+06
# 7660.0       1.186713e+06
#
# [8760 rows x 1 columns]

# %%
# grabbing peak hour
peak_hr = int(kwh_hr_df.index[0])

# calculating end user contribution
end_use_peak = master_df.groupby('hour_ending').sum().iloc[peak_hr]

# sorting values
end_use_peak = end_use_peak.sort_values(ascending=False)

end_use_peak
# Out:
# total       3.536368e+06
# other       1.839027e+06
# plugload    5.848806e+05
# lighting    4.678177e+05
# hvac        2.971412e+05
# process     9.377179e+04
# cooling     8.048195e+04
# poolpump    4.167594e+04
# pumping     2.304538e+04
# Name: 6186.0, dtype: float64

# %%
# creating dataframe of hourly usage by building type - resetting index due to hour_ending conflicts
peak_building_df = master_df.groupby(['hour_ending', 'building_type']).sum().reset_index()

# grabbing peak hour from peak building df
peak_building = peak_building_df[['hour_ending', 'building_type', 'total']].loc[peak_building_df['hour_ending'] == peak_hr]

# sorting df
peak_building =  peak_building.sort_values('total', ascending=False)

peak_building
# Out:
#        hour_ending building_type         total
# 80401       6185.0      res_misc  2.038639e+06
# 80399       6185.0        office  9.029112e+05
# 80402       6185.0        retail  3.468466e+05
# 80397       6185.0     ind_other  1.407064e+05
# 80393       6185.0     comp_elec  7.028613e+04
# 80403       6185.0         water  2.440498e+04
# 80392       6185.0      chemical  1.569327e+04
# 80404       6185.0        wwater  1.175575e+04
# 80398       6185.0        metals  9.080728e+03
# 80394       6185.0          crop  8.211951e+03
# 80396       6185.0      food_bev  5.799386e+03
# 80400       6185.0      plas_rub  2.436232e+03
# 80395       6185.0   data_center  5.514012e+02

# %%
# determining start and end hours for the peak day
start_hr = math.floor(365 - ((8760 - peak_hr) / 24)) * 24
end_hr = math.ceil(365 - ((8760 - peak_hr) / 24)) * 24

# creating plot for peak day's usage
master_df.loc[(master_df['hour_ending'] >= start_hr) & (master_df['hour_ending'] < end_hr)].groupby('hour_ending').sum().plot(
    kind='bar',
    figsize=(14,8)
)

# %%
# creating "hour of day" for each entry
master_df['day_hour'] = master_df['hour_ending'] % 24

# grouping by hour of day and averaging - note used this method instead of .mean() due to some items not have values.. they're different
avg_hr_df = master_df.groupby('day_hour').sum() / 365

# dropping hour ending for plotting
avg_hr_df = avg_hr_df.drop(columns = {'hour_ending'})

# plotting data
avg_hr_df.plot(
    kind='bar',
    figsize=(14,8)
)

# %%
# relatively 'same' as sum std? (what a cluster..)
master_df.groupby('day_hour').std().sum()
# Out:
# cooling         71029.147831
# hour_ending     60691.279504
# hvac           249421.555335
# lighting       409077.989671
# other          373235.073113
# plugload       293308.604289
# poolpump        28781.122193
# process         56078.553603
# pumping         23173.455163
# total          731877.763493
# dtype: float64

# %%
# list of buildings of concern
bld_list = ['office', 'retail']

# creatning dataframe of data based on buildings in bld list
building_lighting_df = master_df[['building_type', 'lighting', 'total']].loc[master_df['building_type'].isin(bld_list)].groupby('building_type').sum()

# calcualted theoretical efficiency ratio
efficiency = 80/110

# calculating LED usage column based on eff ratio
building_lighting_df['lighting_led'] = building_lighting_df['lighting'] * efficiency

# calcualting led savings
building_lighting_df['led_savings'] = building_lighting_df['lighting'] - building_lighting_df['lighting_led']

# calculating total percent savings
building_lighting_df['total_pct_savings'] = (building_lighting_df['led_savings'] / building_lighting_df['total'].sum()) * 100

building_lighting_df
# Out:
#                    lighting         total  lighting_led   led_savings  \
# building_type
# office         1.870954e+09  4.725154e+09  1.360694e+09  5.102602e+08
# retail         1.083402e+09  1.922126e+09  7.879288e+08  2.954733e+08
#
#                total_pct_savings
# building_type
# office                  7.676226
# retail                  4.445025
